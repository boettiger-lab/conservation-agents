# %% [markdown]
# # GYM FISHING WITH PP0

# %%
import gym
import gym_fishing

import numpy as np

from stable_baselines3 import PPO

# %%
env = gym.make('fishing-v0')
env.n_actions = 100
model = PPO('MlpPolicy', env, verbose=1)
# Out:
# Using cpu device
# Wrapping the env in a DummyVecEnv.
# /opt/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))

# %%
model.learn(total_timesteps=200000)
# Out:
# -----------------------------
# | time/              |      |
# |    fps             | 2410 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total timesteps | 2048 |
# -----------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1425       |
# |    iterations           | 2          |
# |    time_elapsed         | 2          |
# |    total timesteps      | 4096       |
# | train/                  |            |
# |    approx_kl            | 0.01535549 |
# |    clip_fraction        | 0.547      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.09      |
# |    explained_variance   | -499       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.03      |
# |    n_updates            | 10         |
# |    policy_gradient_loss | -0.0424    |
# |    value_loss           | 0.0012     |
# ----------------------------------------
# ...

# %%
obs = env.reset()
for i in range(1000) :
    action, _states = model.predict(obs)
    obs, rewards, dones, info = env.step(action)
    env.render()
env.close()

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

data_path = "/Users/kevinab/Desktop/PRe/conservation-agents/fishing.csv"
results = pd.read_csv(data_path, names=['time','state','harvest','action'])

# %%
plt.plot(results.loc[:,'state'])
plt.xlabel('time')
plt.ylabel('state')
# Out:
# Text(0, 0.5, 'state')

# %%
plt.plot(results.loc[:,'harvest'])
plt.xlabel('time')
plt.ylabel('harvest')
# Out:
# Text(0, 0.5, 'harvest')

# %%
plt.plot(results.loc[:,'action'])
plt.xlabel('time')
plt.ylabel('action')
# Out:
# Text(0, 0.5, 'action')
