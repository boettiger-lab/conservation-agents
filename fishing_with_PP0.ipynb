# %% [markdown]
# ### GYM FISHING WITH PPO

# %%
import gym
import gym_fishing

import numpy as np
import tensorflow as tf 

from tf_agents.agents.ppo import ppo_agent

from stable_baselines3 import PPO

# %%
env = gym.make('fishing-v0')
env.n_actions = 100
model = PPO('MlpPolicy', env, verbose=1)
# Out:
# Using cpu device
# Wrapping the env in a DummyVecEnv.

# %%
model.learn(total_timesteps=20000)
# Out:
# -----------------------------
# | time/              |      |
# |    fps             | 2159 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1330        |
# |    iterations           | 2           |
# |    time_elapsed         | 3           |
# |    total timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.015175191 |
# |    clip_fraction        | 0.391       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -47.2       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0403     |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0332     |
# |    value_loss           | 0.00134     |
# ...

# %%
obs = env.reset()
for i in range(1000) :
    action, _states = model.predict(obs)
    obs, rewards, dones, info = env.step(action)
    env.render()
env.close()

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

data_path = "/Users/kevinab/Desktop/PRe/conservation-agents/fishing.csv"
results = pd.read_csv(data_path, names=['time','state','harvest','action'])

# %%
plt.plot(results.loc[0:999,'state'])
plt.xlabel('time')
plt.ylabel('state')
# Out:
# Text(0, 0.5, 'state')

# %%
plt.plot(results.loc[1000:1999,'harvest'])
plt.xlabel('time')
plt.ylabel('harvest')
# Out:
# Text(0, 0.5, 'harvest')

# %%
plt.plot(results.loc[0:999,'action'])
plt.xlabel('time')
plt.ylabel('action')
# Out:
# Text(0, 0.5, 'action')
