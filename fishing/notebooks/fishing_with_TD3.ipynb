# %% [markdown]
# # Fishing with TD3

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


import gym
import gym_fishing

from stable_baselines3 import TD3

# %%
# We use fishing-v1 to test TD3 because it use a continuous action space
env = gym.make('fishing-v1')
env.n_actions = 100
model = TD3('MlpPolicy', env, verbose=1)
# Out:
# Using cpu device
# Wrapping the env in a DummyVecEnv.

# %%
model.learn(total_timesteps=200000)
# Out:
#       |
# |    episodes        | 432      |
# |    fps             | 89       |
# |    time_elapsed    | 7        |
# |    total timesteps | 662      |
# | train/             |          |
# |    learning_rate   | 0.001    |
# |    n_updates       | 558      |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 436      |
# |    fps             | 89       |
# |    time_elapsed    | 7        |
# |    total timesteps | 678      |
# | train/             |          |
# |    learning_rate   | 0.001    |
# |    n_updates       | 574      |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 440      |
# |    fps             | 90       |
# |    time_elapsed    | 7        |
# |    total timesteps | 694      |
# | train/             |          |
# |    learning_rate   | 0.001    |
# |    n_updates       | 590      |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 444      |
# |    fps             | 90       |
# |    time_elapsed    | 7        |
# |    total timesteps | 714      |
# | train/             |          |
# |    learning_rate   | 0.001    |
# |    n_updates       | 609      |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 448      |
# |    fps             | 90       |
# |    time_elapsed    | 8        |
# |    total timesteps | 736      |
# | train/             |          |
# |    learning_rate   | 0.001    |
# |    n_updates       | 630      |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 452      |
# |    fps             | 91       |
# |    time_elapsed    | 8        |
# |    total timesteps | 762      |
# | train/             |          |
# |    learning_rate   | 0.001    |
# |    n_updates       | 655      |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 456      |
# |    fps             | 91       |
# |    time_elapsed    | 8        |
# |    total timesteps | 794      |
# | train/             |          |
# |    learning_rate   | 0.001    |
# |    n_updates       | 685      |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 460      |
# |    fps             | 92       |
# |    time_elapsed    | 9        |
# |    total timesteps | 835      |
# | train/             |          |
# |    learning_rate   | 0.001    |
# |    n_updates       | 724      |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 464      |
# |    fps             | 92       |
# |    time_elapsed    | 9        |
# |    total timesteps | 895      |
# | train/             |          |
# |    learning_rate   | 0.001    |
# |    n_updates       | 777      |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 468      |
# |    fps             | 173      |
# |    time_elapsed    | 11       |
# |    total timesteps | 2006     |
# | train/             |          |
# |    learning_rate   | 0.001    |
# |    n_updates       | 905      |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 472      |
# |    fps             | 103      |
# |    time_elapsed    | 58       |
# |    total timesteps | 6010     |
# | train/             |          |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4909     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 476      |
# |    fps             | 98       |
# |    time_elapsed    | 102      |
# |    total timesteps | 10014    |
# | train/             |          |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8913     |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 480      |
# |    fps             | 97       |
# |    time_elapsed    | 144      |
# |    total timesteps | 14018    |
# | train/             |          |
# |    learning_rate   | 0.001    |
# |    n_updates       | 12917    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 484      |
# |    fps             | 93       |
# |    time_elapsed    | 192      |
# |    total timesteps | 18022    |
# | train/             |          |
# |    learning_rate   | 0.001    |
# |    n_updates       | 16921    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 488      |
# |    fps             | 92       |
# |    time_elapsed    | 237      |
# |    total timesteps | 22026    |
# | train/             |          |
# |    learning_rate   | 0.001    |
# |    n_updates       | 20925    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 492      |
# |    fps             | 91       |
# |    time_elapsed    | 284      |
# |    total timesteps | 26030    |
# | train/             |          |
# |    learning_rate   | 0.001    |
# |    n_updates       | 24929    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 496      |
# |    fps             | 90       |
# |    time_elapsed    | 332      |
# |    total timesteps | 30034    |
# | train/             |          |
# |    learning_rate   | 0.001    |
# |    n_updates       | 28933    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 500      |
# |    fps             | 90       |
# |    time_elapsed    | 374      |
# |    total timesteps | 34038    |
# | train/             |          |
# |    learning_rate   | 0.001    |
# |    n_updates       | 32937    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 504      |
# |    fps             | 90       |
# |    time_elapsed    | 420      |
# |    total timesteps | 38042    |
# | train/             |          |
# |    learning_rate   | 0.001    |
# |    n_updates       | 36941    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 508      |
# |    fps             | 90       |
# |    time_elapsed    | 464      |
# |    total timesteps | 42046    |
# | train/             |          |
# |    learning_rate   | 0.001    |
# |    n_updates       | 40945    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 512      |
# |    fps             | 90       |
# |    time_elapsed    | 507      |
# |    total timesteps | 46050    |
# | train/             |          |
# |    learning_rate   | 0.001    |
# |    n_updates       | 44949    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 516      |
# |    fps             | 90       |
# |    time_elapsed    | 550      |
# |    total timesteps | 50054    |
# | train/             |          |
# |    learning_rate   | 0.001    |
# |    n_updates       | 48953    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 520      |
# |    fps             | 91       |
# |    time_elapsed    | 592      |
# |    total timesteps | 54058    |
# | train/             |          |
# |    learning_rate   | 0.001    |
# |    n_updates       | 52957    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 524      |
# |    fps             | 91       |
# |    time_elapsed    | 636      |
# |    total timesteps | 58062    |
# | train/             |          |
# |    learning_rate   | 0.001    |
# |    n_updates       | 56961    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 528      |
# |    fps             | 91       |
# |    time_elapsed    | 680      |
# |    total timesteps | 62066    |
# | train/             |          |
# |    learning_rate   | 0.001    |
# |    n_updates       | 60965    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 532      |
# |    fps             | 90       |
# |    time_elapsed    | 727      |
# |    total timesteps | 66070    |
# | train/             |          |
# |    learning_rate   | 0.001    |
# |    n_updates       | 64969    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 536      |
# |    fps             | 89       |
# |    time_elapsed    | 781      |
# |    total timesteps | 70074    |
# | train/             |          |
# |    learning_rate   | 0.001    |
# |    n_updates       | 68973    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 540      |
# |    fps             | 88       |
# |    time_elapsed    | 836      |
# |    total timesteps | 74078    |
# | train/             |          |
# |    learning_rate   | 0.001    |
# |    n_updates       | 72977    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 544      |
# |    fps             | 87       |
# |    time_elapsed    | 897      |
# |    total timesteps | 78082    |
# | train/             |          |
# |    learning_rate   | 0.001    |
# |    n_updates       | 76981    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 548      |
# |    fps             | 86       |
# |    time_elapsed    | 953      |
# |    total timesteps | 82086    |
# | train/             |          |
# |    learning_rate   | 0.001    |
# |    n_updates       | 80985    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 552      |
# |    fps             | 85       |
# |    time_elapsed    | 1009     |
# |    total timesteps | 86090    |
# | train/             |          |
# |    learning_rate   | 0.001    |
# |    n_updates       | 84989    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 556      |
# |    fps             | 84       |
# |    time_elapsed    | 1064     |
# |    total timesteps | 90094    |
# | train/             |          |
# |    learning_rate   | 0.001    |
# |    n_updates       | 88993    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 560      |
# |    fps             | 84       |
# |    time_elapsed    | 1114     |
# |    total timesteps | 94098    |
# | train/             |          |
# |    learning_rate   | 0.001    |
# |    n_updates       | 92997    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 564      |
# |    fps             | 83       |
# |    time_elapsed    | 1169     |
# |    total timesteps | 98102    |
# | train/             |          |
# |    learning_rate   | 0.001    |
# |    n_updates       | 97001    |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 568      |
# |    fps             | 83       |
# |    time_elapsed    | 1229     |
# |    total timesteps | 102106   |
# | train/             |          |
# |    learning_rate   | 0.001    |
# |    n_updates       | 101005   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 572      |
# |    fps             | 82       |
# |    time_elapsed    | 1283     |
# |    total timesteps | 106110   |
# | train/             |          |
# |    learning_rate   | 0.001    |
# |    n_updates       | 105009   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 576      |
# |    fps             | 82       |
# |    time_elapsed    | 1340     |
# |    total timesteps | 110114   |
# | train/             |          |
# |    learning_rate   | 0.001    |
# |    n_updates       | 109013   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 580      |
# |    fps             | 81       |
# |    time_elapsed    | 1398     |
# |    total timesteps | 114118   |
# | train/             |          |
# |    learning_rate   | 0.001    |
# |    n_updates       | 113017   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 584      |
# |    fps             | 81       |
# |    time_elapsed    | 1452     |
# |    total timesteps | 118122   |
# | train/             |          |
# |    learning_rate   | 0.001    |
# |    n_updates       | 117021   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 588      |
# |    fps             | 81       |
# |    time_elapsed    | 1505     |
# |    total timesteps | 122126   |
# | train/             |          |
# |    learning_rate   | 0.001    |
# |    n_updates       | 121025   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 592      |
# |    fps             | 80       |
# |    time_elapsed    | 1560     |
# |    total timesteps | 126130   |
# | train/             |          |
# |    learning_rate   | 0.001    |
# |    n_updates       | 125029   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 596      |
# |    fps             | 80       |
# |    time_elapsed    | 1616     |
# |    total timesteps | 130134   |
# | train/             |          |
# |    learning_rate   | 0.001    |
# |    n_updates       | 129033   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 600      |
# |    fps             | 80       |
# |    time_elapsed    | 1670     |
# |    total timesteps | 134138   |
# | train/             |          |
# |    learning_rate   | 0.001    |
# |    n_updates       | 133037   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 604      |
# |    fps             | 80       |
# |    time_elapsed    | 1724     |
# |    total timesteps | 138142   |
# | train/             |          |
# |    learning_rate   | 0.001    |
# |    n_updates       | 137041   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 608      |
# |    fps             | 80       |
# |    time_elapsed    | 1776     |
# |    total timesteps | 142146   |
# | train/             |          |
# |    learning_rate   | 0.001    |
# |    n_updates       | 141045   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 612      |
# |    fps             | 79       |
# |    time_elapsed    | 1831     |
# |    total timesteps | 146150   |
# | train/             |          |
# |    learning_rate   | 0.001    |
# |    n_updates       | 145049   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 616      |
# |    fps             | 79       |
# |    time_elapsed    | 1893     |
# |    total timesteps | 150154   |
# | train/             |          |
# |    learning_rate   | 0.001    |
# |    n_updates       | 149053   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 620      |
# |    fps             | 79       |
# |    time_elapsed    | 1949     |
# |    total timesteps | 154158   |
# | train/             |          |
# |    learning_rate   | 0.001    |
# |    n_updates       | 153057   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 624      |
# |    fps             | 78       |
# |    time_elapsed    | 2015     |
# |    total timesteps | 158162   |
# | train/             |          |
# |    learning_rate   | 0.001    |
# |    n_updates       | 157061   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 628      |
# |    fps             | 78       |
# |    time_elapsed    | 2078     |
# |    total timesteps | 162166   |
# | train/             |          |
# |    learning_rate   | 0.001    |
# |    n_updates       | 161065   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 632      |
# |    fps             | 77       |
# |    time_elapsed    | 2146     |
# |    total timesteps | 166170   |
# | train/             |          |
# |    learning_rate   | 0.001    |
# |    n_updates       | 165069   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 636      |
# |    fps             | 77       |
# |    time_elapsed    | 2201     |
# |    total timesteps | 170174   |
# | train/             |          |
# |    learning_rate   | 0.001    |
# |    n_updates       | 169073   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 640      |
# |    fps             | 77       |
# |    time_elapsed    | 2261     |
# |    total timesteps | 174178   |
# | train/             |          |
# |    learning_rate   | 0.001    |
# |    n_updates       | 173077   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 644      |
# |    fps             | 76       |
# |    time_elapsed    | 2322     |
# |    total timesteps | 178182   |
# | train/             |          |
# |    learning_rate   | 0.001    |
# |    n_updates       | 177081   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 648      |
# |    fps             | 76       |
# |    time_elapsed    | 2384     |
# |    total timesteps | 182186   |
# | train/             |          |
# |    learning_rate   | 0.001    |
# |    n_updates       | 181085   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 652      |
# |    fps             | 75       |
# |    time_elapsed    | 2451     |
# |    total timesteps | 186190   |
# | train/             |          |
# |    learning_rate   | 0.001    |
# |    n_updates       | 185089   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 656      |
# |    fps             | 75       |
# |    time_elapsed    | 2513     |
# |    total timesteps | 190194   |
# | train/             |          |
# |    learning_rate   | 0.001    |
# |    n_updates       | 189093   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 660      |
# |    fps             | 75       |
# |    time_elapsed    | 2582     |
# |    total timesteps | 194198   |
# | train/             |          |
# |    learning_rate   | 0.001    |
# |    n_updates       | 193097   |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 664      |
# |    fps             | 74       |
# |    time_elapsed    | 2649     |
# |    total timesteps | 198202   |
# | train/             |          |
# |    learning_rate   | 0.001    |
# |    n_updates       | 197101   |
# ---------------------------------

# %%
def simulate(environment, model):
  obs = env.reset()
  episode_return = 0.0
  output = np.zeros(shape = (1000, 4))

  for it in range(1000):
    action, _states = model.predict(obs)
    obs, reward, dones, info = env.step(action)  
    episode_return += reward
    output[it] = (it, obs, action, episode_return)
  return output

# %%
out = simulate(env, model)
np.savetxt("td3.csv", out, delimiter=",")

# %% [markdown]
# ### Vizualisation

# %%
datapath = '/Users/kevinab/Desktop/PRe/conservation-agents/td3.csv'
results = pd.read_csv(datapath, names=['time','state','harvest','action'])

# %%
plt.plot(results.iloc[:,1])
plt.ylabel('state')
plt.show()

# %%
plt.plot(results.iloc[:,2])
plt.ylabel('action')
plt.show()

# %%
plt.plot(results.iloc[:,3])
plt.ylabel('reward')
plt.show()
